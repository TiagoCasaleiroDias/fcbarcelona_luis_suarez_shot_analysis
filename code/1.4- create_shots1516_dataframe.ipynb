# %%
import pandas as pd
import numpy as np
import json
from pandas import json_normalize
from math import sqrt

# %%
with open('..\data\matches\\11\\27.json',encoding="utf8") as f:
    data = json.load(f)
    season_15_16 = json_normalize(data)

# %%
ls=[]
for match_id in season_15_16['match_id']: 
    with open('..\data\events\\'+ str(match_id) +'.json',encoding="utf8") as f:
        data = json.load(f)
        match = json_normalize(data)
        ls.append(match)

# %%
lst_concat=[match[(match['type.name']=='Shot') & (match['team.name']=='Barcelona')][['minute','second','player.id','player.name','location','shot.type.id','shot.type.name','shot.body_part.id','shot.body_part.name','shot.technique.id','shot.technique.name','shot.first_time','shot.freeze_frame','shot.outcome.id','shot.outcome.name','shot.end_location']].reset_index() for match in ls]
shots=pd.concat(lst_concat).reset_index().drop('level_0',axis=1)
shots = shots[shots['shot.freeze_frame'].notna()].reset_index(drop=True)
ls1=[[sqrt((di['location'][0] - v['location'][0]) ** 2 + (di['location'][1] - v['location'][1]) ** 2)<2 for v in di['shot.freeze_frame'] if v['teammate']==False] for di in shots.to_dict('records')]
col=[True in element for element in ls1]
shots['under_pressure']=col
shots
# Out:
#      index  minute  second  player.id                     player.name  \
# 0      308       6      18     5246.0        Luis Alberto Suárez Díaz
# 1      505      10      14     5503.0  Lionel Andrés Messi Cuccittini
# 2      509      10      44     5246.0        Luis Alberto Suárez Díaz
# 3      972      22      34     5246.0        Luis Alberto Suárez Díaz
# 4     1020      23      48     5246.0        Luis Alberto Suárez Díaz
# ..     ...     ...     ...        ...                             ...
# 499   2177      49      22     7068.0             Marc Bartra Aregall
# 500   2383      55       3     4320.0   Neymar da Silva Santos Junior
# 501   2388      55       5     4320.0   Neymar da Silva Santos Junior
# 502   3108      75       0     5503.0  Lionel Andrés Messi Cuccittini
# 503   3683      89      15     5503.0  Lionel Andrés Messi Cuccittini
#
#           location  shot.type.id shot.type.name  shot.body_part.id  \
# 0    [109.7, 30.6]          87.0      Open Play               38.0
# 1    [107.1, 34.0]          87.0      Open Play               38.0
# 2    [116.4, 38.9]          87.0      Open Play               38.0
# 3    [112.4, 46.8]          87.0      Open Play               40.0
# 4    [108.7, 38.0]          87.0      Open Play               40.0
# ..             ...           ...            ...                ...
# 499  [114.2, 35.6]          87.0      Open Play               40.0
# 500  [115.0, 36.2]          87.0      Open Play               40.0
# 501  [115.5, 32.7]          87.0      Open Play               40.0
# 502  [108.3, 40.1]          88.0        Penalty               38.0
# 503  [103.6, 38.8]          87.0      Open Play               38.0
#
#     shot.body_part.name  shot.technique.id shot.technique.name  \
# 0             Left Foot               93.0              Normal
# 1             Left Foot               93.0              Normal
# 2             Left Foot               95.0              Volley
# 3            Right Foot               94.0       Overhead Kick
# 4            Right Foot               93.0              Normal
# ..                  ...                ...                 ...
# 499          Right Foot               93.0              Normal
# 500          Right Foot               95.0              Volley
# 501          Right Foot               93.0              Normal
# 502           Left Foot               93.0              Normal
# 503           Left Foot               93.0              Normal
#
#     shot.first_time                                  shot.freeze_frame  \
# 0              True  [{'location': [93.8, 30.1], 'player': {'id': 5...
# 1               NaN  [{'location': [117.6, 37.5], 'player': {'id': ...
# 2              True  [{'location': [116.5, 29.9], 'player': {'id': ...
# 3              True  [{'location': [102.4, 32.9], 'player': {'id': ...
# 4               NaN  [{'location': [113.4, 38.4], 'player': {'id': ...
# ..              ...                                                ...
# 499             NaN  [{'location': [119.7, 37.6], 'player': {'id': ...
# 500            True  [{'location': [119.8, 36.5], 'player': {'id': ...
# 501             NaN  [{'location': [120.0, 34.7], 'player': {'id': ...
# 502             NaN  [{'location': [119.8, 40.0], 'player': {'id': ...
# 503             NaN  [{'location': [107.3, 32.3], 'player': {'id': ...
#
#      shot.outcome.id shot.outcome.name   shot.end_location  under_pressure
# 0               98.0             Off T  [120.0, 34.0, 2.0]            True
# 1              100.0             Saved  [117.5, 37.4, 1.3]            True
# 2               97.0              Goal  [120.0, 37.7, 1.4]            True
# 3               98.0             Off T  [120.0, 49.4, 2.4]           False
# 4               97.0              Goal  [120.0, 38.3, 0.4]           False
# ..               ...               ...                 ...             ...
# 499             97.0              Goal  [120.0, 36.6, 0.2]            True
# 500             96.0           Blocked       [118.3, 37.4]           False
# 501             97.0              Goal  [120.0, 38.2, 0.2]           False
# 502             98.0             Off T  [120.0, 41.1, 3.6]           False
# 503             97.0              Goal  [120.0, 36.5, 0.2]            True
#
# [504 rows x 18 columns]

# %%
shots.to_csv('..\data\produced_datasets\season_15_16_shots.csv')
