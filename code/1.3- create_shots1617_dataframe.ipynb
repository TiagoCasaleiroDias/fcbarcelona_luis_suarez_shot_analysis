# %%
import pandas as pd
import numpy as np
import json
from pandas import json_normalize
from math import sqrt

# %%
with open('..\data\matches\\11\\2.json',encoding="utf8") as f:
    data = json.load(f)
    season_16_17 = json_normalize(data)

# %%
ls=[]
for match_id in season_16_17['match_id']: 
    with open('..\data\events\\'+ str(match_id) +'.json',encoding="utf8") as f:
        data = json.load(f)
        match = json_normalize(data)
        ls.append(match)

# %%
lst_concat=[match[(match['type.name']=='Shot') & (match['team.name']=='Barcelona')][['minute','second','player.id','player.name','location','shot.type.id','shot.type.name','shot.body_part.id','shot.body_part.name','shot.technique.id','shot.technique.name','shot.first_time','shot.freeze_frame','shot.outcome.id','shot.outcome.name','shot.end_location']].reset_index() for match in ls]
shots=pd.concat(lst_concat).reset_index().drop('level_0',axis=1)
shots = shots[shots['shot.freeze_frame'].notna()].reset_index(drop=True)
ls1=[[sqrt((di['location'][0] - v['location'][0]) ** 2 + (di['location'][1] - v['location'][1]) ** 2)<2 for v in di['shot.freeze_frame'] if v['teammate']==False] for di in shots.to_dict('records')]
col=[True in element for element in ls1]
shots['under_pressure']=col
shots
# Out:
#      index  minute  second  player.id                     player.name  \
# 0      293       6      50     5503.0  Lionel Andrés Messi Cuccittini
# 1      961      22      27     5470.0                    Ivan Rakitić
# 2     1152      27       8     5492.0              Samuel Yves Umtiti
# 3     1253      30      13     5503.0  Lionel Andrés Messi Cuccittini
# 4     1380      33      19     6998.0  Rafael Alcântara do Nascimento
# ..     ...     ...     ...        ...                             ...
# 551   3236      79      17     5246.0        Luis Alberto Suárez Díaz
# 552   3321      81      19     5503.0  Lionel Andrés Messi Cuccittini
# 553   3447      83      59     6379.0          Sergi Roberto Carnicer
# 554   3616      90      34     5503.0  Lionel Andrés Messi Cuccittini
# 555   3662      92      54     5503.0  Lionel Andrés Messi Cuccittini
#
#           location  shot.type.id shot.type.name  shot.body_part.id  \
# 0    [104.4, 41.8]          87.0      Open Play               40.0
# 1    [110.8, 35.8]          87.0      Open Play               37.0
# 2    [109.9, 40.5]          87.0      Open Play               37.0
# 3     [90.0, 36.2]          62.0      Free Kick               38.0
# 4     [97.3, 28.8]          87.0      Open Play               40.0
# ..             ...           ...            ...                ...
# 551  [112.1, 42.6]          87.0      Open Play               40.0
# 552  [103.5, 54.1]          87.0      Open Play               40.0
# 553  [107.3, 42.9]          87.0      Open Play               70.0
# 554   [94.8, 43.3]          62.0      Free Kick               38.0
# 555  [101.0, 51.8]          87.0      Open Play               38.0
#
#     shot.body_part.name  shot.technique.id shot.technique.name  \
# 0            Right Foot               93.0              Normal
# 1                  Head               93.0              Normal
# 2                  Head               93.0              Normal
# 3             Left Foot               93.0              Normal
# 4            Right Foot               93.0              Normal
# ..                  ...                ...                 ...
# 551          Right Foot               93.0              Normal
# 552          Right Foot               93.0              Normal
# 553               Other               93.0              Normal
# 554           Left Foot               93.0              Normal
# 555           Left Foot               93.0              Normal
#
#     shot.first_time                                  shot.freeze_frame  \
# 0              True  [{'location': [111.4, 41.5], 'player': {'id': ...
# 1               NaN  [{'location': [106.4, 21.2], 'player': {'id': ...
# 2               NaN  [{'location': [116.0, 63.3], 'player': {'id': ...
# 3               NaN  [{'location': [100.2, 34.5], 'player': {'id': ...
# 4               NaN  [{'location': [99.2, 28.3], 'player': {'id': 2...
# ..              ...                                                ...
# 551            True  [{'location': [101.3, 49.1], 'player': {'id': ...
# 552             NaN  [{'location': [100.8, 50.2], 'player': {'id': ...
# 553             NaN  [{'location': [106.5, 28.6], 'player': {'id': ...
# 554             NaN  [{'location': [118.0, 39.0], 'player': {'id': ...
# 555             NaN  [{'location': [102.0, 51.1], 'player': {'id': ...
#
#      shot.outcome.id shot.outcome.name   shot.end_location  under_pressure
# 0               96.0           Blocked       [107.0, 42.3]           False
# 1               98.0             Off T  [120.0, 51.8, 0.8]            True
# 2              100.0             Saved  [119.4, 41.7, 1.3]            True
# 3               96.0           Blocked       [100.3, 36.3]           False
# 4               96.0           Blocked       [100.4, 31.3]            True
# ..               ...               ...                 ...             ...
# 551            100.0             Saved  [118.4, 42.1, 0.5]           False
# 552            100.0             Saved  [118.4, 41.3, 0.3]            True
# 553             98.0             Off T  [120.0, 38.2, 4.9]            True
# 554             98.0             Off T  [120.0, 38.1, 3.5]           False
# 555             96.0           Blocked       [101.9, 51.2]            True
#
# [556 rows x 18 columns]

# %%
shots.to_csv('..\data\produced_datasets\season_16_17_shots.csv')
